# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

ej2 = pd.read_csv('dataset_2_mejor_caso.csv')

ej2.groupby('Nodos').mean()['Tiempo'].plot()

# %%
ej2rtp = pd.read_csv('dataset_2_random_rt.csv').groupby('Nodos').mean()
ej2rtp['Tiempo'].plot(marker='o')
