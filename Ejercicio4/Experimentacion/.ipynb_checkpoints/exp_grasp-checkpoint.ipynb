# %%
import pandas as pd
import matplotlib.pyplot as plt
import random
import seaborn as sns

df = pd.read_csv('salida-vec-pok.csv')

# %matplotlib inline

# %%
df.head(2)
# Out:
#    gimnasios  pokeparadas  mochila     tiempo  distancia_original  \
# 0         10           22        5  1518000.0             7212.48
# 1         20           44        5  6333000.0            13469.30
#
#    distancia_final  cantidad_de_mejoras  iteraciones  gim_sacados
# 0          5921.12                    1            5            5
# 1         10770.20                    1            5            5

# %%
new_df = df.groupby(['gim_sacados','iteraciones'])[['distancia_original','distancia_final']].mean()

new_df

# new_df = df.groupby(['gim_sacados'])[['distancia_original','distancia_final']].mean()

# new_df

# new_df = df.groupby(['gimnasios','gim_sacados','iteraciones'])[['distancia_original','distancia_final']].mean()

# new_df.head(30)
# Out:
#                          distancia_original  distancia_final
# gim_sacados iteraciones
# 5           5                  46610.805714     36343.072857
#             10                 46610.805714     36070.122857
#             15                 46610.805714     35485.715000
#             20                 46610.805714     35094.893571
#             30                 46610.805714     35476.649286
#             40                 46610.805714     34880.716429
#             50                 46610.805714     34995.142143
# 10          5                  46610.805714     35904.665714
#             10                 46610.805714     35363.408571
#             15                 46610.805714     35080.499286
#             20                 46610.805714     34507.725000
#             30                 46610.805714     34760.359286
#             40                 46610.805714     34766.331429
#             50                 46610.805714     34451.835714
# 15          5                  46610.805714     35932.952143
#             10                 46610.805714     35864.117857
#             15                 46610.805714     35747.022857
#             20                 46610.805714     35586.381429
#             30                 46610.805714     34693.714286
#             40                 46610.805714     34518.682857
#             50                 46610.805714     34492.768571
